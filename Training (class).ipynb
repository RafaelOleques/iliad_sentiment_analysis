# %%
from trainer import Trainer

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
import matplotlib.pyplot as plt

# %%
path = "./data/iliad_sentiments.csv"
target = "class"

# %% [markdown]
# # Standard class

# %% [markdown]
# ## Without lemmatization

# %%
trainer_nb = Trainer(path, target)
trainer_dt = Trainer(path, target)
trainer_knn = Trainer(path, target)

nro_folds = 4
lemmatize = False

trainer_nb.cross_validation(model=MultinomialNB(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=False)
trainer_dt.cross_validation(model=DecisionTreeClassifier(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=True)
trainer_knn.cross_validation(model=KNeighborsClassifier(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=True)
# Out:
# C:\Users\Rafael Oleques\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Rafael Oleques\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Rafael Oleques\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# **Accuracy**

# %%
results=[]
results.append(trainer_nb.get_metric("accuracy"))
results.append(trainer_dt.get_metric("accuracy"))
results.append(trainer_knn.get_metric("accuracy"))

plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.title("Accuracy: standard attributes")
plt.show()

# %% [markdown]
# **Recall**

# %%
results=[]
results.append(trainer_nb.get_metric("recall"))
results.append(trainer_dt.get_metric("recall"))
results.append(trainer_knn.get_metric("recall"))

plt.title("Recall: standard attributes")
plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.show()

# %% [markdown]
# **Precision**

# %%
results=[]
results.append(trainer_nb.get_metric("precision"))
results.append(trainer_dt.get_metric("precision"))
results.append(trainer_knn.get_metric("precision"))

plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.title("Precision: standard attributes")
plt.show()

# %% [markdown]
# ## With lemmatization

# %%
nro_folds = 4
lemmatize = True

trainer_nb_lemma = Trainer(path, target)
trainer_dt_lemma  = Trainer(path, target)
trainer_knn_lemma  = Trainer(path, target)

trainer_nb_lemma.cross_validation(model=MultinomialNB(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=False)
trainer_dt_lemma.cross_validation(model=DecisionTreeClassifier(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=True)
trainer_knn_lemma.cross_validation(model=KNeighborsClassifier(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22720\995894791.py in <module>
#       6 trainer_knn_lemma  = Trainer(path, target)
#       7
# ----> 8 trainer_nb_lemma.cross_validation(model=MultinomialNB(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=False)
#       9 trainer_dt_lemma.cross_validation(model=DecisionTreeClassifier(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=True)
#      10 trainer_knn_lemma.cross_validation(model=KNeighborsClassifier(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=True)
#
# ~\Documents\projetos\iliad_sentiment_analysis\trainer.py in cross_validation(self, model, nro_folds, lemmatize, ohe, shuffle, seed)
#     114         '''
#     115
# --> 116         X, y = self.pre_procession(lemmatize, ohe)
#     117         folds = k_folds(X=X, y=y, k=nro_folds, shuffle=shuffle, seed=seed)
#     118
#
# ...

# %% [markdown]
# **Accuracy**

# %%
results=[]
results.append(trainer_nb_lemma.get_metric("accuracy"))
results.append(trainer_dt_lemma.get_metric("accuracy"))
results.append(trainer_knn_lemma.get_metric("accuracy"))

plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.title("Accuracy: lemmatization")
plt.show()

# %% [markdown]
# **Recall**

# %%
results=[]
results.append(trainer_nb_lemma.get_metric("recall"))
results.append(trainer_dt_lemma.get_metric("recall"))
results.append(trainer_knn_lemma.get_metric("recall"))

plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.title("Recall: lemmatization")

plt.show()

# %% [markdown]
# **Precision**

# %%
results=[]
results.append(trainer_nb_lemma.get_metric("precision"))
results.append(trainer_dt_lemma.get_metric("precision"))
results.append(trainer_knn_lemma.get_metric("precision"))

plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.title("Precision: lemmatization")

plt.show()

# %% [markdown]
# # Without narrator

# %% [markdown]
# ## Without lemmatization

# %%
nro_folds = 4
lemmatize = False

trainer_nb_without_narrator = Trainer(path, target)
trainer_dt_without_narrator   = Trainer(path, target)
trainer_knn_without_narrator   = Trainer(path, target)

trainer_nb_without_narrator.remove_class(["narrator"])
trainer_dt_without_narrator.remove_class(["narrator"])
trainer_knn_without_narrator.remove_class(["narrator"])

trainer_nb_without_narrator.cross_validation(model=MultinomialNB(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=False)
trainer_dt_without_narrator.cross_validation(model=DecisionTreeClassifier(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=True)
trainer_knn_without_narrator.cross_validation(model=KNeighborsClassifier(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=True)

# %% [markdown]
# **Accuracy**

# %%
results=[]
results.append(trainer_nb_without_narrator.get_metric("accuracy"))
results.append(trainer_dt_without_narrator.get_metric("accuracy"))
results.append(trainer_knn_without_narrator.get_metric("accuracy"))

plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.show()

# %% [markdown]
# **Recall**

# %%
results=[]
results.append(trainer_nb_without_narrator.get_metric("recall"))
results.append(trainer_dt_without_narrator.get_metric("recall"))
results.append(trainer_knn_without_narrator.get_metric("recall"))

plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.show()

# %% [markdown]
# **Precision**

# %%
results=[]
results.append(trainer_nb_without_narrator.get_metric("precision"))
results.append(trainer_dt_without_narrator.get_metric("precision"))
results.append(trainer_knn_without_narrator.get_metric("precision"))

plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.show()

# %% [markdown]
# ## With lemmatization

# %%
nro_folds = 4
lemmatize = True

trainer_nb_lemma_without_narrator = Trainer(path, target)
trainer_dt_lemma_without_narrator   = Trainer(path, target)
trainer_knn_lemma_without_narrator   = Trainer(path, target)

trainer_nb_lemma_without_narrator.remove_class(["narrator"])
trainer_dt_lemma_without_narrator.remove_class(["narrator"])
trainer_knn_lemma_without_narrator.remove_class(["narrator"])

trainer_nb_lemma_without_narrator.cross_validation(model=MultinomialNB(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=False)
trainer_dt_lemma_without_narrator.cross_validation(model=DecisionTreeClassifier(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=True)
trainer_knn_lemma_without_narrator.cross_validation(model=KNeighborsClassifier(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=True)

# %% [markdown]
# **Accuracy**

# %%
results=[]
results.append(trainer_nb_lemma_without_narrator.get_metric("accuracy"))
results.append(trainer_dt_lemma_without_narrator.get_metric("accuracy"))
results.append(trainer_knn_lemma_without_narrator.get_metric("accuracy"))

plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.show()

# %% [markdown]
# **Recall**

# %%
results=[]
results.append(trainer_nb_lemma_without_narrator.get_metric("recall"))
results.append(trainer_dt_lemma_without_narrator.get_metric("recall"))
results.append(trainer_knn_lemma_without_narrator.get_metric("recall"))

plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.show()

# %% [markdown]
# **Precision**

# %%
results=[]
results.append(trainer_nb_lemma_without_narrator.get_metric("precision"))
results.append(trainer_dt_lemma_without_narrator.get_metric("precision"))
results.append(trainer_knn_lemma_without_narrator.get_metric("precision"))

plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.show()

# %% [markdown]
# # Merging narrator and neutral

# %% [markdown]
# ## Without lemmatization

# %%
nro_folds = 4
lemmatize = False

trainer_nb_merge_narrator = Trainer(path, target)
trainer_dt_merge_narrator   = Trainer(path, target)
trainer_knn_merge_narrator   = Trainer(path, target)

trainer_nb_merge_narrator.merge_class(["narrator"], "neutral")
trainer_dt_merge_narrator.merge_class(["narrator"], "neutral")
trainer_knn_merge_narrator.merge_class(["narrator"], "neutral")

trainer_nb_merge_narrator.cross_validation(model=MultinomialNB(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=False)
trainer_dt_merge_narrator.cross_validation(model=DecisionTreeClassifier(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=True)
trainer_knn_merge_narrator.cross_validation(model=KNeighborsClassifier(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=True)

# %% [markdown]
# **Accuracy**

# %%
results=[]
results.append(trainer_nb_merge_narrator.get_metric("accuracy"))
results.append(trainer_dt_merge_narrator.get_metric("accuracy"))
results.append(trainer_knn_merge_narrator.get_metric("accuracy"))

plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.show()

# %% [markdown]
# **Recall**

# %%
results=[]
results.append(trainer_nb_merge_narrator.get_metric("recall"))
results.append(trainer_dt_merge_narrator.get_metric("recall"))
results.append(trainer_knn_merge_narrator.get_metric("recall"))

plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.show()

# %% [markdown]
# **Precision**

# %%
results=[]
results.append(trainer_nb_merge_narrator.get_metric("precision"))
results.append(trainer_dt_merge_narrator.get_metric("precision"))
results.append(trainer_knn_merge_narrator.get_metric("precision"))

plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.show()

# %% [markdown]
# ## With lemmatization

# %%
nro_folds = 4
lemmatize = True

trainer_nb_lemma_merge_narrator = Trainer(path, target)
trainer_dt_lemma_merge_narrator   = Trainer(path, target)
trainer_knn_lemma_merge_narrator   = Trainer(path, target)

trainer_nb_lemma_merge_narrator.merge_class(["narrator"], "neutral")
trainer_dt_lemma_merge_narrator.merge_class(["narrator"], "neutral")
trainer_knn_lemma_merge_narrator.merge_class(["narrator"], "neutral")

trainer_nb_lemma_merge_narrator.cross_validation(model=MultinomialNB(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=False)
trainer_dt_lemma_merge_narrator.cross_validation(model=DecisionTreeClassifier(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=True)
trainer_knn_lemma_merge_narrator.cross_validation(model=KNeighborsClassifier(), nro_folds=nro_folds, lemmatize=lemmatize, ohe=True)

# %% [markdown]
# **Accuracy**

# %%
results=[]
results.append(trainer_nb_lemma_merge_narrator.get_metric("accuracy"))
results.append(trainer_dt_lemma_merge_narrator.get_metric("accuracy"))
results.append(trainer_knn_lemma_merge_narrator.get_metric("accuracy"))

plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.show()

# %% [markdown]
# **Recall**

# %%
results=[]
results.append(trainer_nb_lemma_merge_narrator.get_metric("recall"))
results.append(trainer_dt_lemma_merge_narrator.get_metric("recall"))
results.append(trainer_knn_lemma_merge_narrator.get_metric("recall"))

plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.show()

# %% [markdown]
# **Precision**

# %%
results=[]
results.append(trainer_nb_lemma_merge_narrator.get_metric("precision"))
results.append(trainer_dt_lemma_merge_narrator.get_metric("precision"))
results.append(trainer_knn_lemma_merge_narrator.get_metric("precision"))

plt.boxplot(results, labels=["NB", 'DT','KNN'], showmeans=True)
plt.show()

# %% [markdown]
# # Comparing

# %%
from visualizations import compare_boxplot

# %%
metrics_names = ["accuracy", "precision", "recall"]
trainer_name = "Naive Bayes"
labels = ["standard", 'without narrator','merge narrator and neutral']

trainers = [trainer_nb, trainer_nb_without_narrator, trainer_nb_merge_narrator]
trainers_lemma = [trainer_nb_lemma, trainer_nb_lemma_without_narrator, trainer_nb_lemma_merge_narrator]

trainers_list = [trainers, trainers_lemma]


compare_boxplot(metrics_names, trainers_list, trainer_name, labels)

# %%
metrics_names = ["accuracy", "precision", "recall"]

trainers = [trainer_dt, trainer_dt_without_narrator, trainer_dt_merge_narrator]
trainers_lemma = [trainer_dt_lemma, trainer_dt_lemma_without_narrator, trainer_dt_lemma_merge_narrator]
trainers_list = [trainers, trainers_lemma]

trainer_name = "Decision Tree"
labels = ["standard", 'without narrator','merge narrator and neutral']

compare_boxplot(metrics_names, trainers, trainer_name, labels)

# %%
metrics_names = ["accuracy", "precision", "recall"]

trainers = [trainer_knn, trainer_knn_without_narrator, trainer_knn_merge_narrator]
trainers_lemma = [trainer_knn_lemma, trainer_knn_lemma_without_narrator, trainer_knn_lemma_merge_narrator]
trainers_list = [trainers, trainers_lemma]

trainer_name = "KNN"
labels = ["standard", 'without narrator','merge narrator and neutral']

compare_boxplot(metrics_names, trainers, trainer_name, labels)
